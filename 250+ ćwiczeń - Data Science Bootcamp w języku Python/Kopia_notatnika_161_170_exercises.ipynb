# %% [markdown]
# ## Pandas
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 161](#1)
# * [Ćwiczenie 162](#2)
# * [Ćwiczenie 163](#3)
# * [Ćwiczenie 164](#4)
# * [Ćwiczenie 165](#5)
# * [Ćwiczenie 166](#6)
# * [Ćwiczenie 167](#7)
# * [Ćwiczenie 168](#8)
# * [Ćwiczenie 169](#9)
# * [Ćwiczenie 170](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd

pd.options.display.float_format = '{:.2f}'.format
np.__version__
# Out:
# '1.20.3'

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 161
# Wczytaj do obiektu _DataFrame_ o nazwie _df_ plik csv znajdujący się pod linkiem:
# * https://storage.googleapis.com/esmartdata-courses-files/dash-course/data.csv
#
# Ustaw indeks obiektu _df_ na pierwszą kolumnę. Wyświetl obiekt _df_.

# %%
df = pd.read_csv('https://storage.googleapis.com/esmartdata-courses-files/dash-course/data.csv', index_col=0)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp   5.00
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp   5.00
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp   5.00
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp   7.00
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp   5.00
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp   5.00
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp   5.00
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp   8.00
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp   5.00
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp   5.00
#
#       New_Price  Price
# 0           NaN   1.75
# 1           NaN  12.50
# 2     8.61 Lakh   4.50
# 3           NaN   6.00
# 4           NaN  17.74
# ...         ...    ...
# 6014  7.88 Lakh   4.75
# 6015        NaN   4.00
# 6016        NaN   2.90
# 6017        NaN   2.65
# 6018        NaN   2.50
#
# [6019 rows x 13 columns]

# %% [markdown]
# Wyświetl informacje na temat obiektu _df_.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 658.3+ KB

# %% [markdown]
# Wyświetl podstawowe statystyki obiektu _df_.

# %%
df.describe()
# Out:
#          Year  Kilometers_Driven   Seats   Price
# count 6019.00            6019.00 5977.00 6019.00
# mean  2013.36           58738.38    5.28    9.48
# std      3.27           91268.84    0.81   11.19
# min   1998.00             171.00    0.00    0.44
# 25%   2011.00           34000.00    5.00    3.50
# 50%   2014.00           53000.00    5.00    5.64
# 75%   2016.00           73000.00    5.00    9.95
# max   2019.00         6500000.00   10.00  160.00

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 162
# Znajdź listę zawierającą nazwy wszystkich kolumn obiektu _df_.

# %%
list(df.columns)
# Out:
# ['Name',
#  'Location',
#  'Year',
#  'Kilometers_Driven',
#  'Fuel_Type',
#  'Transmission',
#  'Owner_Type',
#  'Mileage',
#  'Engine',
#  'Power',
#  'Seats',
#  'New_Price',
#  'Price']

# %% [markdown]
# Z obiektu _df_ usuń kolumnę o nazwie _New_Price_ i wyświetl 5 pierwszych wierszy.

# %%
del df['New_Price']
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp   5.00
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp   5.00
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp   5.00
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp   7.00
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp   5.00
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 163
# Znajdź liczbę brakujących wartości dla każdej zmiennej obiektu _df_.

# %%
df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %% [markdown]
# Usuń wszystkie wiersze z obiektu _df_ zawierające braki danych. Użyj parametru _inplace=True_.

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5975 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5975 non-null   object
#  1   Location           5975 non-null   object
#  2   Year               5975 non-null   int64
#  3   Kilometers_Driven  5975 non-null   int64
#  4   Fuel_Type          5975 non-null   object
#  5   Transmission       5975 non-null   object
#  6   Owner_Type         5975 non-null   object
#  7   Mileage            5975 non-null   object
#  8   Engine             5975 non-null   object
#  9   Power              5975 non-null   object
#  10  Seats              5975 non-null   float64
#  11  Price              5975 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 606.8+ KB

# %% [markdown]
# Wyświetl raz jeszcze informacje na temat obiektu _df_. Zwróć uwagę na liczbę wierszy i typ danych.

# %%
df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 164
# Zamień wszystkie litery w nazwach kolumn na małe, np.:
# * Name -> name
# * Fuel_Type -> fuel_type
#
# Wyświetl metodą _head()_ pięć pierwszych wierszy.

# %%
df.columns=df.columns.str.lower()
df.head()
# Out:
#                                name    location  year  kilometers_driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   fuel_type transmission owner_type     mileage   engine      power  seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp   5.00
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp   5.00
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp   5.00
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp   7.00
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp   5.00
#
#    price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 165
# Znajdź rozkład wartości zmiennej _owner_type_.

# %%
df['owner_type'].value_counts()
# Out:
# First             4903
# Second             953
# Third              111
# Fourth & Above       8
# Name: owner_type, dtype: int64

# %% [markdown]
# Znajdź rozkład wartości zmiennej _engine_.

# %%
df['engine'].value_counts()
# Out:
# 1197 CC    606
# 1248 CC    512
# 1498 CC    303
# 998 CC     259
# 2179 CC    240
#           ...
# 1489 CC      1
# 1422 CC      1
# 1978 CC      1
# 2694 CC      1
# 1797 CC      1
# Name: engine, Length: 145, dtype: int64

# %% [markdown]
# Zauważ, że zmienna _engine_ jest typu _object_. Usuń 3 ostatnie znaki z każdego elementu i resztę skonwertuj na typ int. Wyświetl metodą _head()_ pięć pierwszych wierszy.

# %%
df['engine'] = df['engine'].map(lambda x: int(x[:-3]))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14364/1450149154.py in <module>
# ----> 1 df['engine'] = df['engine'].map(lambda x: int(x[:-3]))
#       2 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_14364/1450149154.py in <lambda>(x)
# ----> 1 df['engine'] = df['engine'].map(lambda x: int(x[:-3]))
#       2 df.head()
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 166
# Spójrz na rozkład zmiennej _power_. Zauważ, że ta zmienna ma także braki danych w postaci wartości _'null bhp'_. Zamień te wartości dla zmiennej _power_ na wartość _np.nan_. Wykorzystaj przy tym funkcję _np.where()_.

# %%
df[df['power']=='null bhp']
# Out:
# Empty DataFrame
# Columns: [name, location, year, kilometers_driven, fuel_type, transmission, owner_type, mileage, engine, power, seats, new_price, price]
# Index: []

# %% [markdown]
# Usuń jeszcze raz wszystkie rekordy z brakami danych.

# %%
# tutaj wpisz rozwiązanie

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 167
# Zauważ, że zmienna _power_ jest typu _object_. Usuń 4 ostatnie znaki z każdego elementu i resztę skonwertuj na typ float.
#
# Wyświetl metodą _head()_ pięć pierwszych wierszy.

# %%
df['power'] = df['power'].map(lambda x: float(x[:-4]))
df['power'].astype(float)
df
# Out:
#                                    name location  year  kilometers_driven  \
# 2                          Honda Jazz V  Chennai  2011              46000
# 7     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                     Maruti Ciaz Zeta    Kochi  2018              25692
# 15          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5999              Tata Bolt Revotron XT  Chennai  2016              10000
# 6002      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 6005           Maruti Vitara Brezza VDi     Pune  2016              37208
# 6010               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 6014                   Maruti Swift VDI    Delhi  2014              27365
#
#      fuel_type transmission owner_type     mileage  engine  power  seats  \
# 2       Petrol       Manual      First   18.2 kmpl    1199  88.70   5.00
# 7       Diesel    Automatic      First  11.36 kmpl    2755 171.50   8.00
# 10      Petrol       Manual      First  21.56 kmpl    1462 103.25   5.00
# 15      Diesel       Manual      First   13.5 kmpl    2477 175.56   7.00
# 20      Diesel    Automatic      First  22.69 kmpl    1995 190.00   5.00
# ...        ...          ...        ...         ...     ...    ...    ...
# 5999    Petrol       Manual      First  17.57 kmpl    1193  88.70   5.00
# 6002    Petrol       Manual      First  16.09 kmpl    1598 103.50   5.00
# 6005    Diesel       Manual      First   24.3 kmpl    1248  88.50   5.00
# 6010    Petrol       Manual      First   18.5 kmpl    1198  86.80   5.00
# 6014    Diesel       Manual      First   28.4 kmpl    1248  74.00   5.00
#
#        new_price  price
# 2      8.61 Lakh   4.50
# 7        21 Lakh  17.50
# 10    10.65 Lakh   9.95
# 15    32.01 Lakh  15.00
# 20    47.87 Lakh  18.55
# ...          ...    ...
# 5999   7.77 Lakh   4.00
# 6002  11.91 Lakh   3.25
# 6005   9.93 Lakh   7.43
# 6010   6.63 Lakh   3.20
# 6014   7.88 Lakh   4.75
#
# [823 rows x 13 columns]

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 168
# Pogrupuj dane na poziomie roku (_year_) i policz liczbę rekordów dla każdego roku w obiekcie _df_.

# %%
df.groupby('year').size()
# Out:
# year
# 2001      1
# 2004      1
# 2005      1
# 2007      1
# 2008      4
# 2009      3
# 2010     16
# 2011     23
# 2012     34
# 2013     45
# 2014     59
# 2015     70
# 2016    155
# 2017    215
# 2018    137
# 2019     58
# dtype: int64

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 169
# Sprawdź rozkład zmiennej _transmission_.

# %%
df['transmission'].value_counts()
# Out:
# Manual       512
# Automatic    311
# Name: transmission, dtype: int64

# %% [markdown]
# Dokonaj następującego mapowania zmiennej _transmission_:
# * Manual -> 0
# * Automatic -> 1
#
# Wyświetl metodą _head()_ pięć pierwszych wierszy.

# %%
df['transmission'] = df['transmission'].map({'Manual':0, 'Automatic':1})
df
# Out:
#                                    name location  year  kilometers_driven  \
# 2                          Honda Jazz V  Chennai  2011              46000
# 7     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                     Maruti Ciaz Zeta    Kochi  2018              25692
# 15          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5999              Tata Bolt Revotron XT  Chennai  2016              10000
# 6002      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 6005           Maruti Vitara Brezza VDi     Pune  2016              37208
# 6010               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 6014                   Maruti Swift VDI    Delhi  2014              27365
#
#      fuel_type  transmission owner_type     mileage  engine  power  seats  \
# 2       Petrol             0      First   18.2 kmpl    1199  88.70   5.00
# 7       Diesel             1      First  11.36 kmpl    2755 171.50   8.00
# 10      Petrol             0      First  21.56 kmpl    1462 103.25   5.00
# 15      Diesel             0      First   13.5 kmpl    2477 175.56   7.00
# 20      Diesel             1      First  22.69 kmpl    1995 190.00   5.00
# ...        ...           ...        ...         ...     ...    ...    ...
# 5999    Petrol             0      First  17.57 kmpl    1193  88.70   5.00
# 6002    Petrol             0      First  16.09 kmpl    1598 103.50   5.00
# 6005    Diesel             0      First   24.3 kmpl    1248  88.50   5.00
# 6010    Petrol             0      First   18.5 kmpl    1198  86.80   5.00
# 6014    Diesel             0      First   28.4 kmpl    1248  74.00   5.00
#
#        new_price  price
# 2      8.61 Lakh   4.50
# 7        21 Lakh  17.50
# 10    10.65 Lakh   9.95
# 15    32.01 Lakh  15.00
# 20    47.87 Lakh  18.55
# ...          ...    ...
# 5999   7.77 Lakh   4.00
# 6002  11.91 Lakh   3.25
# 6005   9.93 Lakh   7.43
# 6010   6.63 Lakh   3.20
# 6014   7.88 Lakh   4.75
#
# [823 rows x 13 columns]

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 170
# Zapisz obiekt _df_ do pliku _car.csv_ (nie zapisuj indeksu).

# %%
df.to_csv

# %% [markdown]
# Uruchom poniższą instrukcję w celu sprawdzenia.

# %%
# !head car.csv
