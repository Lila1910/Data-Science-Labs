# %%
import pandas as pd
import numpy as np
mrbean=pd.read_csv("./course-files/mrbean_facebook_statuses_join.csv",usecols=['status_message_mrbean','status_type','num_likes'])
mrbean.head()
# Out:
#                                status_message_mrbean status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa=pd.read_csv("./course-files/nasa_facebook_statuses_join.csv",usecols=['status_message_nasa','status_type','num_likes'])
nasa.head()
# Out:
#                                  status_message_nasa status_type  num_likes
# 0  This morning, the #RockOn mission with student...       photo       5142
# 1  Pluto's largest moon, Charon, is home to an un...       photo      19074
# 2  Our Restore-L mission is an endeavor to launch...       photo       7551
# 3  A new dark vortex was discovered in the atmosp...       photo      24359
# 4                                                NaN       video       2731

# %%
fb=mrbean.append(nasa,sort=True)

# %%
fb.head(10)
# Out:
#    num_likes                              status_message_mrbean  \
# 0      16079  It's time for Mr Bean and Teddy to get ready f...
# 1     114008                                                NaN
# 2     218579                                                NaN
# 3      20338  Mr Bean is ready to do some shopping but bewar...
# 4     215591                                                NaN
# 5      23977            Mr. Bean's sweet treat causes him pain!
# 6      21246  Mr Bean's chasing a ray of sunshine!\nhttps://...
# 7      21293  Mr Bean is enjoying the sunshine....that is un...
# 8     190476                                                NaN
# 9     190857                                                NaN
#
#   status_message_nasa status_type
# 0                 NaN       video
# 1                 NaN       photo
# 2                 NaN       photo
# 3                 NaN       video
# 4                 NaN       photo
# 5                 NaN       video
# 6                 NaN       video
# 7                 NaN       video
# 8                 NaN       photo
# 9                 NaN       photo

# %%
fb.tail(10)
# Out:
#      num_likes status_message_mrbean  \
# 753       1298                   NaN
# 754       8012                   NaN
# 755      19639                   NaN
# 756       8794                   NaN
# 757      15706                   NaN
# 758      39355                   NaN
# 759      11835                   NaN
# 760      15567                   NaN
# 761      41584                   NaN
# 762      12793                   NaN
#
#                                    status_message_nasa status_type
# 753  Today's The New York Times featured Instagram ...       photo
# 754  El Niño, a natural weather phenomenon, caused ...       video
# 755  Our Interstellar Boundary Explorer, or IBEX, s...       photo
# 756  Cue the confetti! After almost 12 months livin...       video
# 757  Hard at work, our Mars Opportunity rover exami...       photo
# 758  You've never seen Pluto like this before! New ...       photo
# 759  Our cooperative field study in East Asia advan...       photo
# 760  After spending a #YearInSpace, astronaut Scott...       photo
# 761  Gravitational waves, predicted by Einstein and...       photo
# 762  Have you ever used a GPS to help you get somew...       photo

# %%
fb.loc[0]
# Out:
#    num_likes                              status_message_mrbean  \
# 0      16079  It's time for Mr Bean and Teddy to get ready f...
# 0       5142                                                NaN
#
#                                  status_message_nasa status_type
# 0                                                NaN       video
# 0  This morning, the #RockOn mission with student...       photo

# %%
fb=mrbean.append(nasa,sort=True,ignore_index=True)fb=mrbean.append(nasa,sort=True,ignore_index=True)

# %%
fb.head()
# Out:
#    num_likes                              status_message_mrbean  \
# 0      16079  It's time for Mr Bean and Teddy to get ready f...
# 1     114008                                                NaN
# 2     218579                                                NaN
# 3      20338  Mr Bean is ready to do some shopping but bewar...
# 4     215591                                                NaN
#
#   status_message_nasa status_type
# 0                 NaN       video
# 1                 NaN       photo
# 2                 NaN       photo
# 3                 NaN       video
# 4                 NaN       photo

# %%
fb.tail()
# Out:
#      num_likes status_message_mrbean  \
# 814      39355                   NaN
# 815      11835                   NaN
# 816      15567                   NaN
# 817      41584                   NaN
# 818      12793                   NaN
#
#                                    status_message_nasa status_type
# 814  You've never seen Pluto like this before! New ...       photo
# 815  Our cooperative field study in East Asia advan...       photo
# 816  After spending a #YearInSpace, astronaut Scott...       photo
# 817  Gravitational waves, predicted by Einstein and...       photo
# 818  Have you ever used a GPS to help you get somew...       photo

# %%
fb.loc[0]
# Out:
# num_likes                                                            16079
# status_message_mrbean    It's time for Mr Bean and Teddy to get ready f...
# status_message_nasa                                                    NaN
# status_type                                                          video
# Name: 0, dtype: object

# %%
mrbean.rename({'status_message_mrbean':'status_message'},axis='columns',inplace=True)

# %%
nasa.rename({'status_message_nasa':'status_message'},axis='columns',inplace=True)

# %%
fb=mrbean.append(nasa,sort=True,ignore_index=True)

# %%
fb.head()
# Out:
#    num_likes                                     status_message status_type
# 0      16079  It's time for Mr Bean and Teddy to get ready f...       video
# 1     114008                                                NaN       photo
# 2     218579                                                NaN       photo
# 3      20338  Mr Bean is ready to do some shopping but bewar...       video
# 4     215591                                                NaN       photo

# %%
concatenated=pd.concat(objs=[nasa,mrbean],ignore_index=True)
concatenated.head()
# Out:
#                                       status_message status_type  num_likes
# 0  This morning, the #RockOn mission with student...       photo       5142
# 1  Pluto's largest moon, Charon, is home to an un...       photo      19074
# 2  Our Restore-L mission is an endeavor to launch...       photo       7551
# 3  A new dark vortex was discovered in the atmosp...       photo      24359
# 4                                                NaN       video       2731
